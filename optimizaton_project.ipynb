# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
print(os.listdir("../downloads/"))
# Out:
# ['Hinal_SOP_IS.pdf', 'homework-1 (1).docx', 'Robot PPT.ppt', 'googlechrome.dmg', 'i2ml3e-chap1.pptx', 'EligibilityResultsNotice.pdf', 'List of Acceptable Docs for I-9.pdf', 'Worker Guide_ExpressClock (002).docx', 'IMG_2739.HEIC', 'DisclosureStatement (1).pdf', '2(d).png', 'INTRODUCTION TO FPGA’S.pptx', 'Homework 5.docx', 'Question1.docx', 'CambridgeGrammarforIELTS (1).pdf', 'NON-DRIVER ID.ics', 'PlainLanguageDisclosure (1).pdf', 'Introduction to Data Science 5-13.pptx', 'CPE517-HW1.pdf', 'temp.csv', 'Resume202109281104.pdf', '2021012019482093054.pdf', 'C15.zip', 'IdentityProofingFailureNotice (1).pdf', 'HinalPatel_HW8.pdf', 'IdentityProofingFailureNotice.pdf', 'Duolingo English Test-2.0.1.dmg', '.DS_Store', 'homework-1.docx', 'Smiths Medical Contingent Worker - Entering Timecards Acceleration (1).docx', 'FreeRTOSv202107.00.zip', 'MyStudentData (1).csv', 'Lecture 7 Hardware Software Partitioning_2021F_Posted.pptx', 'IMG_2738.HEIC', '59626702020AUSW201.xml.pdf', 'Duolingo English Test-
# ...

# %%
customers = pd.read_csv('../Desktop/Ecommerce Customers.csv')

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
#comment
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
sns.jointplot(x='Time on Website',y ='Yearly Amount Spent', data = customers)

# %%
sns.jointplot(x='Time on App',y ='Yearly Amount Spent', data = customers)

# %%
sns.jointplot(x='Length of Membership',y ='Yearly Amount Spent', data = customers)

# %%
sns.jointplot(x='Avg. Session Length',y ='Yearly Amount Spent', data = customers)

# %%
sns.jointplot(x='Time on App',y ='Length of Membership', data = customers, kind='hex')

# %%
sns.pairplot(customers)

# %%
sns.set(color_codes=True)
sns.lmplot(x='Length of Membership', y='Yearly Amount Spent',data=customers)

# %%
X = customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]

# %%
from sklearn import preprocessing
normalized_X = preprocessing.normalize(X)

# %%
y= customers['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train )
# Out:
# LinearRegression()

# %%
# normaized data o/p
print(lm.coef_)
# Out:
# [25.98154972 38.59015875  0.19040528 61.27909654]

# %%
print(lm.coef_)
# Out:
# [25.98154972 38.59015875  0.19040528 61.27909654]

# %%
print(lm.intercept_)
# Out:
# -1047.932782250238

# %%
predictions = lm.predict(X_test)

# %%
plt.pyplot.scatter(y_test, predictions)
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
sns.distplot((y_test-predictions))
# Out:
# /Users/hinalpatel/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, predictions)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, predictions)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, predictions))))
print('r2_square: {}'. format(metrics.r2_score(y_test, predictions)))
# Out:
# MAE: 7.228148653430847
# MSE: 79.81305165097477
# RMSE: 8.933815066978651
# r2_square: 0.9890046246741234

# %%
pd.DataFrame(lm.coef_ , X.columns, columns=['Coeffecient'])
# Out:
#                       Coeffecient
# Avg. Session Length     25.981550
# Time on App             38.590159
# Time on Website          0.190405
# Length of Membership    61.279097

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = predictions
print(results_pd)
results_pd.to_excel("results_excel.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   456.441861
# 361  401.033135   402.720053
# 104  410.069611   409.253154
# 4    599.406092   591.431034
# 156  586.155870   590.014373
# ..          ...          ...
# 147  479.731938   478.300766
# 346  488.387526   484.410296
# 423  461.112248   457.590999
# 17   407.704548   411.526576
# 259  375.398455   375.479006
#
# [150 rows x 2 columns]

# %%
m = lm.coef_
b = lm.intercept_
X = customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
x1 = X_test[['Avg. Session Length']].to_numpy()
x2 = X_test[['Time on App']].to_numpy()
x3 = X_test[['Time on Website']].to_numpy()
x4 = X_test[['Length of Membership']].to_numpy()
y1 = (m[0]*x1)+(m[1]*x2)+(m[2]*x3)+(m[3]*x4)+b
print('the coefficients of the model are:', lm.coef_)
print('the intercept of the model are:', lm.intercept_)
print(y1)
# Out:
# the coefficients of the model are: [25.98154972 38.59015875  0.19040528 61.27909654]
# the intercept of the model are: -1047.932782250238
# [[456.44186104]
#  [402.72005312]
#  [409.2531539 ]
#  [591.4310343 ]
#  [590.01437275]
#  [548.82396607]
#  [577.59737969]
#  [715.44428115]
#  [473.7893446 ]
#  [545.9211364 ]
#  [337.8580314 ]
#  [500.38506697]
#  [552.93478041]
#  [409.6038964 ]
#  [765.52590754]
#  [545.83973731]
#  [693.25969124]
#  [507.32416226]
#  [573.10533175]
#  [573.2076631 ]
#  [397.44989709]
#  [555.0985107 ]
#  [458.19868141]
#  [482.66899911]
#  [559.2655959 ]
#  [413.00946082]
#  [532.25727408]
#  [377.65464817]
#  [535.0209653 ]
#  [447.80070905]
#  [595.54339577]
#  [667.14347072]
#  [511.96042791]
#  [573.30433971]
#  [505.02260887]
#  [565.30254655]
#  [460.38785393]
#  [449.74727868]
#  [422.87193429]
#  [456.55615271]
#  [598.10493696]
#  [449.64517443]
#  [615.34948995]
#  [511.88078685]
#  [504.37568058]
#  [515.95249276]
#  [568.64597718]
# ...

# %%
print((np.array((y_test, predictions))))
# Out:
# [[452.31567548 401.03313522 410.06961106 599.40609205 586.15587018
#   535.48077519 588.71260551 712.39632681 462.89763615 532.72480546
#   327.37795259 492.5568337  543.34016626 403.7669021  765.51846194
#   537.84619527 708.93518487 501.92826487 564.79096901 571.21600483
#   408.64035107 548.51852928 467.4278485  490.6004425  571.47103412
#   410.60294395 534.77148495 368.65478495 540.26340041 443.44186006
#   605.0610388  640.18774001 493.18021625 568.71757593 501.10024523
#   560.44379217 447.68790654 432.48116856 436.58074035 461.92087689
#   587.57479948 445.74984124 632.12358814 505.11334354 506.13234244
#   518.06455798 577.73602485 541.97220376 356.61556789 472.99224667
#   467.80092437 552.94034545 256.67058229 487.54750487 521.24078024
#   304.13559158 507.39006179 387.35707274 478.88539132 426.15454771
#   537.2150527  590.56271965 744.2218671  544.40927216 533.04006018
#   439.99787994 434.02169975 502.4097853  642.10157873 476.19141335
# ...

# %%
sns.heatmap(customers.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

regressor = SGDRegressor(n_iter_no_change=250, fit_intercept=True, alpha=0.0001, penalty='l2', eta0=0.0001, max_iter=100000)

regressor = regressor.fit(X_train, y_train)
y_predn = regressor.predict(X_test)

# %%
regressor.fit(X_train, y_train )
# Out:
# SGDRegressor(eta0=0.0001, max_iter=100000, n_iter_no_change=250)

# %%
print(regressor.coef_)
# Out:
# [ 12.89544485  33.53048843 -14.54896243  59.23683267]

# %%
predictions = regressor.predict(X_test)

# %%
plt.pyplot.scatter(y_test, predictions)
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, predictions)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, predictions)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, predictions))))
print('r2_square: {}'. format(metrics.r2_score(y_test, predictions)))
# Out:
# MAE: 17.94642141637505
# MSE: 501.45886180741894
# RMSE: 22.39327715649094
# r2_square: 0.9309169580412587

# %%
sns.distplot((y_test-predictions))
# Out:
# /Users/hinalpatel/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
pd.DataFrame(regressor.coef_ , X.columns, columns=['Coeffecient'])
# Out:
#                       Coeffecient
# Avg. Session Length     12.895445
# Time on App             33.530488
# Time on Website        -14.548962
# Length of Membership    59.236833

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = predictions
print(results_pd)
results_pd.to_excel("results_excel1.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   440.094102
# 361  401.033135   394.188966
# 104  410.069611   420.774257
# 4    599.406092   574.287502
# 156  586.155870   589.983730
# ..          ...          ...
# 147  479.731938   489.712990
# 346  488.387526   504.067607
# 423  461.112248   468.991550
# 17   407.704548   402.948626
# 259  375.398455   390.544322
#
# [150 rows x 2 columns]

# %%
m = regressor.coef_
b = regressor.intercept_
X = customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
x1 = X_test[['Avg. Session Length']].to_numpy()
x2 = X_test[['Time on App']].to_numpy()
x3 = X_test[['Time on Website']].to_numpy()
x4 = X_test[['Length of Membership']].to_numpy()
y1 = (m[0]*x1)+(m[1]*x2)+(m[2]*x3)+(m[3]*x4)+b
print('the coefficients of the model are:', regressor.coef_)
print('the intercept of the model are:', regressor.intercept_)
print(y1)
# Out:
# the coefficients of the model are: [ 12.89544485  33.53048843 -14.54896243  59.23683267]
# the intercept of the model are: [-1.82113203]
# [[440.09410222]
#  [394.18896566]
#  [420.77425678]
#  [574.28750208]
#  [589.98373   ]
#  [536.80086061]
#  [599.94149908]
#  [663.80185879]
#  [476.45004612]
#  [541.93565083]
#  [353.9824508 ]
#  [486.05037021]
#  [529.66597333]
#  [428.25338443]
#  [726.61245803]
#  [557.86696035]
#  [679.29528098]
#  [503.96053688]
#  [560.20536827]
#  [572.26832337]
#  [441.82234743]
#  [554.35576512]
#  [417.50509238]
#  [492.22551392]
#  [572.86727994]
#  [412.20946852]
#  [526.46584066]
#  [366.00023068]
#  [538.5497987 ]
#  [429.3064855 ]
#  [587.56624296]
#  [622.83491216]
#  [492.75356472]
#  [577.42207893]
#  [491.50624785]
#  [534.77845388]
#  [481.48840681]
#  [468.1873201 ]
#  [427.4986689 ]
#  [458.69242638]
#  [611.45544102]
#  [433.73472212]
#  [587.80456574]
#  [530.08277204]
#  [490.74203529]
#  [531.95186027]
#  [591.67170034]
# ...

# %%
print((np.array((y_test, predictions))))
# Out:
# [[452.31567548 401.03313522 410.06961106 599.40609205 586.15587018
#   535.48077519 588.71260551 712.39632681 462.89763615 532.72480546
#   327.37795259 492.5568337  543.34016626 403.7669021  765.51846194
#   537.84619527 708.93518487 501.92826487 564.79096901 571.21600483
#   408.64035107 548.51852928 467.4278485  490.6004425  571.47103412
#   410.60294395 534.77148495 368.65478495 540.26340041 443.44186006
#   605.0610388  640.18774001 493.18021625 568.71757593 501.10024523
#   560.44379217 447.68790654 432.48116856 436.58074035 461.92087689
#   587.57479948 445.74984124 632.12358814 505.11334354 506.13234244
#   518.06455798 577.73602485 541.97220376 356.61556789 472.99224667
#   467.80092437 552.94034545 256.67058229 487.54750487 521.24078024
#   304.13559158 507.39006179 387.35707274 478.88539132 426.15454771
#   537.2150527  590.56271965 744.2218671  544.40927216 533.04006018
#   439.99787994 434.02169975 502.4097853  642.10157873 476.19141335
# ...

# %%
from sklearn.linear_model import Ridge

model = Ridge(alpha=100, fit_intercept=True, normalize=False, solver='cholesky', tol=0.0001, random_state=42)
model=model.fit(X_train, y_train)
predec = model.predict(X_test)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=100, random_state=42, solver='cholesky', tol=0.0001)

# %%
print(model.coef_)
# Out:
# [20.07894318 29.33346945  0.40118477 47.63154598]

# %%
print(model.intercept_)
# Out:
# -701.0551276873248

# %%
plt.pyplot.scatter(y_test,predec)
plt.pyplot.ylabel('Pred')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
sns.distplot((y_test-predec))
# Out:
# /Users/hinalpatel/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, predec)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, predec)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, predec))))
print('r2_square: {}'. format(metrics.r2_score(y_test, predec)))
# Out:
# MAE: 17.02184128109594
# MSE: 472.3339268912561
# RMSE: 21.733244739137692
# r2_square: 0.9349293292527413

# %%
pd.DataFrame(model.coef_ , X.columns, columns=['Coeffecient'])
# Out:
#                       Coeffecient
# Avg. Session Length     20.078943
# Time on App             29.333469
# Time on Website          0.401185
# Length of Membership    47.631546

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = predec
print(results_pd)
results_pd.to_excel("results_excel2.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   464.475288
# 361  401.033135   425.825823
# 104  410.069611   430.310096
# 4    599.406092   570.360497
# 156  586.155870   569.560079
# ..          ...          ...
# 147  479.731938   484.033243
# 346  488.387526   486.997549
# 423  461.112248   467.722769
# 17   407.704548   431.370746
# 259  375.398455   403.923445
#
# [150 rows x 2 columns]

# %%
m = model.coef_
b = model.intercept_
X = customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
x1 = X_test[['Avg. Session Length']].to_numpy()
x2 = X_test[['Time on App']].to_numpy()
x3 = X_test[['Time on Website']].to_numpy()
x4 = X_test[['Length of Membership']].to_numpy()
y1 = (m[0]*x1)+(m[1]*x2)+(m[2]*x3)+(m[3]*x4)+b
print('the coefficients of the model are:', model.coef_)
print('the intercept of the model are:', model.intercept_)
print(y1)
# Out:
# the coefficients of the model are: [20.07894318 29.33346945  0.40118477 47.63154598]
# the intercept of the model are: -701.0551276873248
# [[464.47528818]
#  [425.82582348]
#  [430.31009561]
#  [570.36049717]
#  [569.56007942]
#  [537.26205096]
#  [558.88328439]
#  [665.92496224]
#  [479.57743362]
#  [535.3591528 ]
#  [374.27140635]
#  [498.98282037]
#  [540.4881496 ]
#  [429.84003746]
#  [703.92104012]
#  [534.91937917]
#  [649.10119069]
#  [505.14586043]
#  [555.35510068]
#  [555.30432816]
#  [421.20755875]
#  [542.11576627]
#  [466.92538892]
#  [486.41712897]
#  [545.17283516]
#  [433.47876653]
#  [524.15802132]
#  [404.36924078]
#  [526.02288797]
#  [460.07396409]
#  [572.76123149]
#  [627.89091832]
#  [508.21391702]
#  [556.56661412]
#  [503.61215032]
#  [550.99823369]
#  [469.27777587]
#  [460.80267006]
#  [439.1168755 ]
#  [465.50978939]
#  [576.1085063 ]
#  [461.61181019]
#  [588.98021507]
#  [508.72981071]
#  [502.82893415]
#  [510.98950131]
#  [553.15761885]
# ...

# %%
l = (np.array(( predec - y_test)))

# %%
print(np.array((l/y_test)*100))
# Out:
# [ 2.68830230e+00  6.18220443e+00  4.93586552e+00 -4.84572901e+00
#  -2.83129311e+00  3.32649808e-01 -5.06687318e+00 -6.52324596e+00
#   3.60334471e+00  4.94504350e-01  1.43239499e+01  1.30461832e+00
#  -5.24904440e-01  6.45747218e+00 -8.04649723e+00 -5.44173432e-01
#  -8.43998090e+00  6.41046895e-01 -1.67068329e+00 -2.78557963e+00
#   3.07537120e+00 -1.16728290e+00 -1.07494575e-01 -8.52692571e-01
#  -4.60184286e+00  5.57127583e+00 -1.98467269e+00  9.68777764e+00
#  -2.63584622e+00  3.75068425e+00 -5.33827254e+00 -1.92081493e+00
#   3.04831789e+00 -2.13655465e+00  5.01277961e-01 -1.68537124e+00
#   4.82252681e+00  6.54860918e+00  5.80908620e-01  7.76953950e-01
#  -1.95146102e+00  3.55849122e+00 -6.82514842e+00  7.15971419e-01
#  -6.52676782e-01 -1.36567085e+00 -4.25426232e+00 -5.25447182e-01
#   9.20039882e+00 -1.89740365e-01  3.88480049e+00 -4.80846151e+00
#   2.12614801e+01  3.43990473e+00 -8.88591520e-01  1.71768154e+01
# ...

# %%
from sklearn.linear_model import Lasso

model = Lasso(alpha=0.1, 
              precompute=True, 
               warm_start=True, 
              positive=True, 
              selection='random',
              random_state=101)
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
plt.pyplot.scatter(y_test,pred )
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
print(model.coef_)
# Out:
# [25.88089815 38.48560358  0.09176682 61.17679879]

# %%
print(model.intercept_)
# Out:
# -1039.3301180681062

# %%
m = model.coef_
b = model.intercept_
X = customers[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']]
x1 = X_test[['Avg. Session Length']].to_numpy()
x2 = X_test[['Time on App']].to_numpy()
x3 = X_test[['Time on Website']].to_numpy()
x4 = X_test[['Length of Membership']].to_numpy()
y1 = (m[0]*x1)+(m[1]*x2)+(m[2]*x3)+(m[3]*x4)+b
print('the coefficients of the model are:', model.coef_)
print('the intercept of the model are:', model.intercept_)
print(y1)
# Out:
# the coefficients of the model are: [25.88089815 38.48560358  0.09176682 61.17679879]
# the intercept of the model are: -1039.3301180681062
# [[456.33871839]
#  [402.80943139]
#  [409.44053375]
#  [591.1837055 ]
#  [589.86341391]
#  [548.67335294]
#  [577.59669329]
#  [714.81020521]
#  [473.90269571]
#  [545.80983167]
#  [338.1955791 ]
#  [500.28709672]
#  [552.67375826]
#  [409.8861564 ]
#  [764.87185631]
#  [545.8390949 ]
#  [692.91282587]
#  [507.27792797]
#  [572.90470639]
#  [573.04885259]
#  [397.82900278]
#  [555.04175821]
#  [458.01260425]
#  [482.7504971 ]
#  [559.25668665]
#  [413.17807952]
#  [532.16384767]
#  [377.73041548]
#  [534.97247768]
#  [447.74082469]
#  [595.31612877]
#  [666.62238647]
#  [511.83178637]
#  [573.27770267]
#  [504.92543396]
#  [565.03255858]
#  [460.61732202]
#  [449.94374494]
#  [423.01887369]
#  [456.59474757]
#  [598.082876  ]
#  [449.59778105]
#  [614.98772193]
#  [511.97770232]
#  [504.32406795]
#  [516.00615239]
#  [568.75134037]
# ...

# %%
plt.pyplot.scatter(y_test,pred )
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
sns.distplot((y_test-pred))
# Out:
# /Users/hinalpatel/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Yearly Amount Spent', ylabel='Density'>

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, pred)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, pred)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, pred))))
print('r2_square: {}'. format(metrics.r2_score(y_test, pred)))
# Out:
# MAE: 7.23766914657653
# MSE: 80.1599471117953
# RMSE: 8.95320876065086
# r2_square: 0.9889568349240554

# %%
pd.DataFrame(model.coef_ , X.columns, columns=['Coeffecient'])
# Out:
#                       Coeffecient
# Avg. Session Length     25.880898
# Time on App             38.485604
# Time on Website          0.091767
# Length of Membership    61.176799

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = pred
print(results_pd)
results_pd.to_excel("results_excel3.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   456.338718
# 361  401.033135   402.809431
# 104  410.069611   409.440534
# 4    599.406092   591.183705
# 156  586.155870   589.863414
# ..          ...          ...
# 147  479.731938   478.416218
# 346  488.387526   484.554013
# 423  461.112248   457.758752
# 17   407.704548   411.584343
# 259  375.398455   375.758888
#
# [150 rows x 2 columns]

# %%
print((np.array((y_test, pred))))
# Out:
# [[452.31567548 401.03313522 410.06961106 599.40609205 586.15587018
#   535.48077519 588.71260551 712.39632681 462.89763615 532.72480546
#   327.37795259 492.5568337  543.34016626 403.7669021  765.51846194
#   537.84619527 708.93518487 501.92826487 564.79096901 571.21600483
#   408.64035107 548.51852928 467.4278485  490.6004425  571.47103412
#   410.60294395 534.77148495 368.65478495 540.26340041 443.44186006
#   605.0610388  640.18774001 493.18021625 568.71757593 501.10024523
#   560.44379217 447.68790654 432.48116856 436.58074035 461.92087689
#   587.57479948 445.74984124 632.12358814 505.11334354 506.13234244
#   518.06455798 577.73602485 541.97220376 356.61556789 472.99224667
#   467.80092437 552.94034545 256.67058229 487.54750487 521.24078024
#   304.13559158 507.39006179 387.35707274 478.88539132 426.15454771
#   537.2150527  590.56271965 744.2218671  544.40927216 533.04006018
#   439.99787994 434.02169975 502.4097853  642.10157873 476.19141335
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_reg = PolynomialFeatures(degree=2)

X_train_2_d = poly_reg.fit_transform(X_train)
X_test_2_d = poly_reg.transform(X_test)

# %%
lin_reg = LinearRegression(normalize=True)
lin_reg.fit(X_train_2_d,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
test_pred = lin_reg.predict(X_test_2_d)
train_pred = lin_reg.predict(X_train_2_d)

# %%
plt.pyplot.scatter(y_test,test_pred )
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, test_pred)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, test_pred)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, test_pred))))
print('r2_square: {}'. format(metrics.r2_score(y_test, test_pred)))
# Out:
# MAE: 7.432195703827283
# MSE: 85.34745505511977
# RMSE: 9.238368636026589
# r2_square: 0.9882421824247092

# %%
print(lin_reg.coef_)
# Out:
# [ 0.00000000e+00  8.62205925e+01  4.23488013e+01 -3.70180338e+01
#   6.94610748e+01 -8.52575304e-01 -1.63938829e-01 -6.96300892e-02
#   1.54747525e-01  4.09647871e-01 -2.23931429e-01  4.22973815e-02
#   5.86109438e-01 -3.63615756e-01 -4.29311091e-02]

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = test_pred
print(results_pd)
results_pd.to_excel("results_excel4.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   460.142472
# 361  401.033135   405.996787
# 104  410.069611   408.151568
# 4    599.406092   591.451373
# 156  586.155870   589.373352
# ..          ...          ...
# 147  479.731938   478.375556
# 346  488.387526   485.344897
# 423  461.112248   458.567385
# 17   407.704548   412.757127
# 259  375.398455   375.505749
#
# [150 rows x 2 columns]

# %%
print((np.array((y_test, test_pred))))
# Out:
# [[452.31567548 401.03313522 410.06961106 599.40609205 586.15587018
#   535.48077519 588.71260551 712.39632681 462.89763615 532.72480546
#   327.37795259 492.5568337  543.34016626 403.7669021  765.51846194
#   537.84619527 708.93518487 501.92826487 564.79096901 571.21600483
#   408.64035107 548.51852928 467.4278485  490.6004425  571.47103412
#   410.60294395 534.77148495 368.65478495 540.26340041 443.44186006
#   605.0610388  640.18774001 493.18021625 568.71757593 501.10024523
#   560.44379217 447.68790654 432.48116856 436.58074035 461.92087689
#   587.57479948 445.74984124 632.12358814 505.11334354 506.13234244
#   518.06455798 577.73602485 541.97220376 356.61556789 472.99224667
#   467.80092437 552.94034545 256.67058229 487.54750487 521.24078024
#   304.13559158 507.39006179 387.35707274 478.88539132 426.15454771
#   537.2150527  590.56271965 744.2218671  544.40927216 533.04006018
#   439.99787994 434.02169975 502.4097853  642.10157873 476.19141335
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()

# %%
regressor.fit(X_train, y_train)
pred = regressor.predict(X_test)

# %%
plt.pyplot.scatter(y_test,pred )
plt.pyplot.ylabel('Predicted')
plt.pyplot.xlabel('Y test')
# Out:
# Text(0.5, 0, 'Y test')

# %%
regressor.fit(X_train, y_train)
print(regressor.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-e15d914ad352> in <module>
#       1 regressor.fit(X_train, y_train)
# ----> 2 print(regressor.coef_)
#
# AttributeError: 'DecisionTreeRegressor' object has no attribute 'coef_'

# %%
import sklearn.metrics as metrics
print('MAE: {}'.format(metrics.mean_absolute_error(y_test, pred)))
print('MSE: {}'.format(metrics.mean_squared_error(y_test, pred)))
print('RMSE: {}'.format(np.sqrt(metrics.mean_squared_error(y_test, pred))))
print('r2_square: {}'. format(metrics.r2_score(y_test, pred)))
# Out:
# MAE: 23.402834092514908
# MSE: 918.3111058131291
# RMSE: 30.303648391128238
# r2_square: 0.8734896728608817

# %%
results_pd = pd.DataFrame()
results_pd['y_test'] = y_test
results_pd['predictions'] = pred
print(results_pd)
results_pd.to_excel("results_excel5.xlsx")
# Out:
#          y_test  predictions
# 18   452.315675   432.472061
# 361  401.033135   392.285244
# 104  410.069611   430.588883
# 4    599.406092   591.197178
# 156  586.155870   684.163431
# ..          ...          ...
# 147  479.731938   488.786061
# 346  488.387526   478.584286
# 423  461.112248   463.923513
# 17   407.704548   420.737673
# 259  375.398455   378.330907
#
# [150 rows x 2 columns]

# %%
print((np.array((y_test, pred))))
# Out:
# [[452.31567548 401.03313522 410.06961106 599.40609205 586.15587018
#   535.48077519 588.71260551 712.39632681 462.89763615 532.72480546
#   327.37795259 492.5568337  543.34016626 403.7669021  765.51846194
#   537.84619527 708.93518487 501.92826487 564.79096901 571.21600483
#   408.64035107 548.51852928 467.4278485  490.6004425  571.47103412
#   410.60294395 534.77148495 368.65478495 540.26340041 443.44186006
#   605.0610388  640.18774001 493.18021625 568.71757593 501.10024523
#   560.44379217 447.68790654 432.48116856 436.58074035 461.92087689
#   587.57479948 445.74984124 632.12358814 505.11334354 506.13234244
#   518.06455798 577.73602485 541.97220376 356.61556789 472.99224667
#   467.80092437 552.94034545 256.67058229 487.54750487 521.24078024
#   304.13559158 507.39006179 387.35707274 478.88539132 426.15454771
#   537.2150527  590.56271965 744.2218671  544.40927216 533.04006018
#   439.99787994 434.02169975 502.4097853  642.10157873 476.19141335
# ...
